# %%
import pandas as pd
import json
import pyarrow
import random
import os
import time

# %%
def create_sample_data(n_rows = 1000):

    data = {
        'id': range(n_rows),
        'name': [f'User_{i}' for i in range(n_rows)],
        'age': [random.randint(18, 65) for _ in range(n_rows)],
        'salary': [random.uniform(45000, 150000) for _ in range(n_rows)],
        'department': [random.choice(['Engineering', 'Sales', 'Marketing', 'HR']) for _ in range(n_rows)],
        'active': [random.choice([True, False]) for _ in range(n_rows)]
    }

    return pd.DataFrame(data)

# %%
# Create the data frame
print("running pandas_data_types.py")
df = create_sample_data(n_rows=100)
print(f"Created dataframe with {len(df)} rows and {len(df.columns)} columns")
print(df.head())
# Out:
# running pandas_data_types.py
# Created dataframe with 100 rows and 6 columns
#    id    name  age         salary department  active
# 0   0  User_0   28   49284.356183         HR    True
# 1   1  User_1   23  102038.446610      Sales   False
# 2   2  User_2   40   49406.625625  Marketing    True
# 3   3  User_3   31  121131.631845  Marketing    True
# 4   4  User_4   38  116465.960065         HR    True

# %%
# Save the data frame to different formats
start = time.time()
df.to_csv("sample_data.csv", index=False)
csv_time = time.time() - start
print("Dataframe saved to sample_data.csv")

start = time.time()
df.to_json("sample_data.json", orient="records", lines=True)
json_time = time.time() - start
print("Dataframe saved to sample_data.json")

start = time.time()
df.to_parquet("sample_data.parquet", index=False)
parquet_time = time.time() - start
print("Dataframe saved to sample_data.parquet")

print()
print("write times:")
print(f"sample_data.csv: {csv_time} seconds")
print(f"sample_data.json: {json_time} seconds")
print(f"sample_data.parquet: {parquet_time} seconds")
# Out:
# Dataframe saved to sample_data.csv
# Dataframe saved to sample_data.json
# Dataframe saved to sample_data.parquet
#
# write times:
# sample_data.csv: 0.005540370941162109 seconds
# sample_data.json: 0.0026426315307617188 seconds
# sample_data.parquet: 0.023502349853515625 seconds

# %%
# Print file sizes
print()
print("File sizes:")
print(f"sample_data.csv: {os.path.getsize('sample_data.csv')} bytes")
print(f"sample_data.json: {os.path.getsize('sample_data.json')} bytes")
print(f"sample_data.parquet: {os.path.getsize('sample_data.parquet')} bytes")
# Out:
# File sizes:
# sample_data.csv: 4599 bytes
# sample_data.json: 9963 bytes
# sample_data.parquet: 5967 bytes

# %%
# Load the data frame from different formats
start = time.time()
df = pd.read_csv("sample_data.csv")
csv_time_in = time.time() - start
print("Dataframe read from sample_data.csv")

start = time.time()
df = pd.read_json("sample_data.json", orient="records", lines=True)
json_time_in = time.time() - start
print("Dataframe read from sample_data.json")

start = time.time()
df =  pd.read_parquet("sample_data.parquet")
parquet_time_in = time.time() - start
print("Dataframe read from sample_data.parquet")

print()
print("read times:")
print(f"sample_data.csv: {csv_time_in} seconds")
print(f"sample_data.json: {json_time_in} seconds")
print(f"sample_data.parquet: {parquet_time_in} seconds")
# Out:
# Dataframe read from sample_data.csv
# Dataframe read from sample_data.json
# Dataframe read from sample_data.parquet
#
# read times:
# sample_data.csv: 0.0063741207122802734 seconds
# sample_data.json: 0.019685983657836914 seconds
# sample_data.parquet: 0.02603292465209961 seconds
